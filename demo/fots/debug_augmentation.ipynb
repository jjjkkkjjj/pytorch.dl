# %% [markdown]
# # Augmentation

# %%
import sys
sys.path.append('../../')

from dl.data.txtdetn import datasets, target_transforms, transforms, augmentations
# %load_ext autoreload
# %autoreload 2

# %matplotlib notebook
import matplotlib.pyplot as plt
from dl.data.utils.converter import toVisualizeQuadsRGBimg
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Random Resize for longer side

# %%
augmentation = augmentations.RandomLongerResize(640, 2560, p=1)

ignore = target_transforms.Ignore(strange=True)

transform = transforms.Compose(
    [#transforms.Resize((640, 640)),
     transforms.ToTensor(),]
     #transforms.Normalize(rgb_means=(0.485, 0.456, 0.406), rgb_stds=(0.229, 0.224, 0.225))]
)
target_transform = target_transforms.Compose(
    [target_transforms.Text2Number(class_labels=datasets.SynthText_char_labels_without_upper_blank, ignore_nolabel=False),
     target_transforms.ToTensor(textTensor=True)]
)

train_dataset = datasets.SynthTextDetectionDataset(ignore=ignore, transform=transform, target_transform=target_transform, augmentation=augmentation,
                                                   onlyAlphaNumeric=False)

indices = [1, 100, 150, 10000]

for index in indices:
    img, targets, texts = train_dataset[index]
    
    for txt in texts:
        print(''.join([datasets.SynthText_char_labels_without_upper_blank[c.item()] for c in txt]))
    
    locs = targets[:, 4:12]
    
    img = toVisualizeQuadsRGBimg(img, locs)#, , texts)
    
    plt.figure()
    plt.imshow(img)
# Out:
# time
# you
# played
# so
# fine
# trw
# apr
# <img src="data:image/png;base64,..." width="640">
# looked
# pretty
# good
# there.
# but
# then
# neither
# used
# to
# seeing
# for
# both
# make
# dod
# cap
# key
# and
# the
# newsgroups:
# <img src="data:image/png;base64,..." width="640">
# map.
# mars
# launched
# will
# martian
# effects
# nci
# result
# effects
# of
# the
# <img src="data:image/png;base64,..." width="640">
# hill
# (such
# the
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Random Rotate

# %%
augmentation = augmentations.RandomRotate(amin=-10, amax=10, p=1)

ignore = target_transforms.Ignore(strange=True)

transform = transforms.Compose(
    [#transforms.Resize((640, 640)),
     transforms.ToTensor(),]
     #transforms.Normalize(rgb_means=(0.485, 0.456, 0.406), rgb_stds=(0.229, 0.224, 0.225))]
)
target_transform = target_transforms.Compose(
    [target_transforms.Text2Number(class_labels=datasets.SynthText_char_labels_without_upper_blank, ignore_nolabel=False),
     target_transforms.ToTensor(textTensor=True)]
)

train_dataset = datasets.SynthTextDetectionDataset(ignore=ignore, transform=transform, target_transform=target_transform, augmentation=augmentation,
                                                   onlyAlphaNumeric=False)

indices = [1, 100, 150, 10000]

for index in indices:
    img, targets, texts = train_dataset[index]
    
    for txt in texts:
        print(''.join([datasets.SynthText_char_labels_without_upper_blank[c.item()] for c in txt]))
    
    locs = targets[:, 4:12]
    
    img = toVisualizeQuadsRGBimg(img, locs)#, , texts)
    
    plt.figure()
    plt.imshow(img)
# Out:
# time
# you
# played
# so
# fine
# trw
# apr
# <img src="data:image/png;base64,..." width="640">
# looked
# pretty
# good
# there.
# but
# then
# neither
# used
# to
# seeing
# for
# both
# make
# dod
# cap
# key
# and
# the
# newsgroups:
# <img src="data:image/png;base64,..." width="640">
# map.
# mars
# launched
# will
# martian
# effects
# nci
# result
# effects
# of
# the
# <img src="data:image/png;base64,..." width="640">
# hill
# (such
# the
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Random Scale

# %%
augmentation = augmentations.RandomScaleH(smin=0.8, smax=1.2, keep_aspect=True, p=1)

ignore = target_transforms.Ignore(strange=True)

transform = transforms.Compose(
    [#transforms.Resize((640, 640)),
     transforms.ToTensor(),]
     #transforms.Normalize(rgb_means=(0.485, 0.456, 0.406), rgb_stds=(0.229, 0.224, 0.225))]
)
target_transform = target_transforms.Compose(
    [target_transforms.Text2Number(class_labels=datasets.SynthText_char_labels_without_upper_blank, ignore_nolabel=False),
     target_transforms.ToTensor(textTensor=True)]
)

train_dataset = datasets.SynthTextDetectionDataset(ignore=ignore, transform=transform, target_transform=target_transform, augmentation=augmentation,
                                                   onlyAlphaNumeric=False)

indices = [1, 100, 150, 10000]

for index in indices:
    img, targets, texts = train_dataset[index]
    
    for txt in texts:
        print(''.join([datasets.SynthText_char_labels_without_upper_blank[c.item()] for c in txt]))
    
    locs = targets[:, 4:12]
    
    img = toVisualizeQuadsRGBimg(img, locs)#, , texts)
    
    plt.figure()
    plt.imshow(img)
# Out:
# (368, 600, 3)
# (363, 593, 3)
# time
# you
# played
# so
# fine
# trw
# apr
# <img src="data:image/png;base64,..." width="640">
# (600, 600, 3)
# (534, 534, 3)
# looked
# pretty
# good
# there.
# but
# then
# neither
# used
# to
# seeing
# for
# both
# make
# dod
# cap
# key
# and
# the
# newsgroups:
# <img src="data:image/png;base64,..." width="640">
# (600, 388, 3)
# (569, 368, 3)
# map.
# mars
# launched
# will
# martian
# effects
# nci
# result
# effects
# of
# the
# <img src="data:image/png;base64,..." width="640">
# (400, 600, 3)
# (417, 625, 3)
# hill
# (such
# the
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Random Sample

# %%
augmentation = augmentations.RandomSampledSize(w=640, h=640)

ignore = target_transforms.Ignore(strange=True)

transform = transforms.Compose(
    [#transforms.Resize((640, 640)),
     transforms.ToTensor(),]
     #transforms.Normalize(rgb_means=(0.485, 0.456, 0.406), rgb_stds=(0.229, 0.224, 0.225))]
)
target_transform = target_transforms.Compose(
    [target_transforms.Text2Number(class_labels=datasets.SynthText_char_labels_without_upper_blank, ignore_nolabel=False),
     target_transforms.ToTensor(textTensor=True)]
)

train_dataset = datasets.SynthTextDetectionDataset(ignore=ignore, transform=transform, target_transform=target_transform, augmentation=augmentation,
                                                   onlyAlphaNumeric=False)

indices = [1, 100, 150, 10000]

for index in indices:
    img, targets, texts = train_dataset[index]
    
    for txt in texts:
        print(''.join([datasets.SynthText_char_labels_without_upper_blank[c.item()] for c in txt]))
    
    locs = targets[:, 4:12]
    
    img = toVisualizeQuadsRGBimg(img, locs)#, , texts)
    
    plt.figure()
    plt.imshow(img)
# Out:
# WARNING:root:Option does not contain EntireSample. May not be able to return value in worst case
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-cc48aae4bc2d> in <module>
#      19
#      20 for index in indices:
# ---> 21     img, targets, texts = train_dataset[index]
#      22
#      23     for txt in texts:
#
# ~/Desktop/program/machile-learning/pytorch.dl/dl/data/txtdetn/datasets/synthtext.py in __getitem__(self, index)
#      56         while True:
#      57             try:
# ---> 58                 return super().__getitem__(ind)
#      59             except _FoundNonAlphaNumeric:
#      60                 ind = np.random.randint(0, len(self))
#
# ~/Desktop/program/machile-learning/pytorch.dl/dl/data/txtdetn/datasets/base.py in __getitem__(self, index)
#      22         targets = self._get_target(index)
#      23
# ---> 24         img, targets = self.apply_transform(img, *targets)
#      25
#      26         labels, bboxes, flags, quads, texts = targets[:]
#
# ~/Desktop/program/machile-learning/pytorch.dl/dl/data/txtdetn/datasets/base.py in apply_transform(self, img, *targets)
#      47         quads[:, 1::2] /= float(height)
#      48
# ---> 49         return super().apply_transform(img, labels, bboxes, flags, quads, texts)
#      50
#
# ~/Desktop/program/machile-learning/pytorch.dl/dl/data/objdetn/datasets/base.py in apply_transform(self, img, *targets)
#     116             targets = (labels, bboxes, flags, *args)
#     117
# --> 118         return super().apply_transform(img, *targets)
#     119
#     120     @abc.abstractmethod
#
# ~/Desktop/program/machile-learning/pytorch.dl/dl/data/objrecog/datasets/base.py in apply_transform(self, img, *targets)
#      65
#      66         if self.augmentation:
# ---> 67             img, targets = self.augmentation(img, *targets)
#      68
#      69         if self.transform:
#
# ~/Desktop/program/machile-learning/pytorch.dl/dl/data/txtdetn/augmentations.py in __call__(self, img, labels, bboxes, flags, *args)
#     237             for _ in range(self.max_iteration):
#     238                 try:
# --> 239                     return op(img, labels, bboxes, flags, *args)
#     240                 except _SampledPatchOp.UnSatisfy:
#     241                     continue
#
# ~/Desktop/program/machile-learning/pytorch.dl/dl/data/txtdetn/augmentations.py in __call__(self, img, labels, bboxes, flags, quads, texts)
#     287
#     288         # patch_h, patch_w = int(aspect_ratio*h), int(aspect_ratio*w)
# --> 289         patch_topleft_x = random.randint(w - patch_w)
#     290         patch_topleft_y = random.randint(h - patch_h)
#     291         # shape = (1, 4)
#
# mtrand.pyx in numpy.random.mtrand.RandomState.randint()
#
# _bounded_integers.pyx in numpy.random._bounded_integers._rand_int64()
#
# ValueError: low >= high
